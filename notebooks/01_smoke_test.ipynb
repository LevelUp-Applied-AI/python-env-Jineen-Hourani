# %%
import pandas as pd

df = pd.read_csv("../data/sample.csv")
print("Shape:", df.shape)
print(df.head())
print(df.describe())
# Out:
# Shape: (4, 3)
#      name  age  score
# 0  Jineen   23     92
# 1    Lina   25     88
# 2    Omar   22     75
# 3    Sara   24     81
#              age      score
# count   4.000000   4.000000
# mean   23.500000  84.000000
# std     1.290994   7.527727
# min    22.000000  75.000000
# 25%    22.750000  79.500000
# 50%    23.500000  84.500000
# 75%    24.250000  89.000000
# max    25.000000  92.000000

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\ASUS\aispire\python-env-Jineen-Hourani\notebooks
